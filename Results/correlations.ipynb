# %%
## japan
ex_rates <- read.csv('topfive.csv')
ex_rates <- subset(ex_rates, ex_rates$Country.y=='japan')
    
full <- subset(ex_rates, select = c(Pct_Chg, Exchange, X1Y_Yield_d, 
                X1Y_Yield_f, Int_d, Int_f,  Infl_d, Infl_f, GDPG_d,
                GDPG_f, BOT_f, BOT_d, FER_f))

print('japan')
full <- full[,-1]
rownames(full) <- 1:nrow(full)
round(cor(full,use="complete"),2)
# Out:
# [1] "japan"
#             Exchange X1Y_Yield_d X1Y_Yield_f Int_d Int_f Infl_d Infl_f GDPG_d
# Exchange        1.00        0.09       -0.56  0.63  0.87   0.67   0.75   0.52
# X1Y_Yield_d     0.09        1.00       -0.02  0.05 -0.06  -0.14  -0.13   0.17
# X1Y_Yield_f    -0.56       -0.02        1.00 -0.14 -0.43  -0.31  -0.70  -0.24
# Int_d           0.63        0.05       -0.14  1.00  0.70   0.73   0.40   0.52
# Int_f           0.87       -0.06       -0.43  0.70  1.00   0.78   0.77   0.62
# Infl_d          0.67       -0.14       -0.31  0.73  0.78   1.00   0.70   0.45
# Infl_f          0.75       -0.13       -0.70  0.40  0.77   0.70   1.00   0.40
# GDPG_d          0.52        0.17       -0.24  0.52  0.62   0.45   0.40   1.00
# GDPG_f         -0.68       -0.02        0.97 -0.20 -0.54  -0.44  -0.80  -0.31
# BOT_f          -0.17        0.23        0.22  0.14 -0.09  -0.23  -0.30   0.08
# BOT_d           0.62        0.19       -0.29  0.63  0.73   0.50   0.46   0.81
# FER_f          -0.62       -0.22        0.23 -0.75 -0.70  -0.52  -0.39  -0.72
#             GDPG_f BOT_f BOT_d FER_f
# Exchange     -0.68 -0.17  0.62 -0.62
# X1Y_Yield_d  -0.02  0.23  0.19 -0.22
# X1Y_Yield_f   0.97  0.22 -0.29  0.23
# Int_d        -0.20  0.14  0.63 -0.75
# Int_f        -0.54 -0.09  0.73 -0.70
# Infl_d       -0.44 -0.23  0.50 -0.52
# Infl_f       -0.80 -0.30  0.46 -0.39
# GDPG_d       -0.31  0.08  0.81 -0.72
# GDPG_f        1.00  0.27 -0.36  0.30
# BOT_f         0.27  1.00  0.20 -0.43
# BOT_d        -0.36  0.20  1.00 -0.90
# FER_f         0.30 -0.43 -0.90  1.00

# %%
## europe
ex_rates <- read.csv('topfive.csv')
ex_rates <- subset(ex_rates, ex_rates$Country.y=='europe')
    
full <- subset(ex_rates, select = c(Pct_Chg, Exchange, X1Y_Yield_d, 
                X1Y_Yield_f, Int_d, Int_f,  Infl_d, Infl_f, GDPG_d,
                GDPG_f, BOT_f, BOT_d, FER_f))

print('europe')
full <- full[,-1]
rownames(full) <- 1:nrow(full)
round(cor(full,use="complete"),2)
# Out:
# [1] "europe"
#             Exchange X1Y_Yield_d X1Y_Yield_f Int_d Int_f Infl_d Infl_f GDPG_d
# Exchange        1.00        0.14        0.24  0.44  0.46   0.01   0.03   0.14
# X1Y_Yield_d     0.14        1.00        0.61  0.16 -0.13   0.17  -0.06   0.12
# X1Y_Yield_f     0.24        0.61        1.00  0.50  0.14   0.30   0.01  -0.06
# Int_d           0.44        0.16        0.50  1.00  0.77   0.50   0.28  -0.11
# Int_f           0.46       -0.13        0.14  0.77  1.00   0.53   0.58  -0.07
# Infl_d          0.01        0.17        0.30  0.50  0.53   1.00   0.79  -0.19
# Infl_f          0.03       -0.06        0.01  0.28  0.58   0.79   1.00  -0.13
# GDPG_d          0.14        0.12       -0.06 -0.11 -0.07  -0.19  -0.13   1.00
# GDPG_f         -0.20        0.13       -0.06 -0.54 -0.75  -0.46  -0.53  -0.06
# BOT_f           0.08        0.14       -0.03 -0.42 -0.53  -0.49  -0.53   0.02
# BOT_d           0.55        0.06       -0.08 -0.04 -0.02  -0.45  -0.40   0.49
# FER_f          -0.16        0.06       -0.10 -0.60 -0.70  -0.36  -0.37   0.26
#             GDPG_f BOT_f BOT_d FER_f
# Exchange     -0.20  0.08  0.55 -0.16
# X1Y_Yield_d   0.13  0.14  0.06  0.06
# X1Y_Yield_f  -0.06 -0.03 -0.08 -0.10
# Int_d        -0.54 -0.42 -0.04 -0.60
# Int_f        -0.75 -0.53 -0.02 -0.70
# Infl_d       -0.46 -0.49 -0.45 -0.36
# Infl_f       -0.53 -0.53 -0.40 -0.37
# GDPG_d       -0.06  0.02  0.49  0.26
# GDPG_f        1.00  0.73 -0.04  0.65
# BOT_f         0.73  1.00  0.18  0.51
# BOT_d        -0.04  0.18  1.00  0.33
# FER_f         0.65  0.51  0.33  1.00

# %%
## korea
ex_rates <- read.csv('topfive.csv')
ex_rates <- subset(ex_rates, ex_rates$Country.y=='korea')
    
full <- subset(ex_rates, select = c(Pct_Chg, Exchange, X1Y_Yield_d, 
                X1Y_Yield_f, Int_d, Int_f,  Infl_d, Infl_f, GDPG_d,
                GDPG_f, BOT_f, BOT_d, FER_f))

print('korea')
full <- full[,-1]
rownames(full) <- 1:nrow(full)
round(cor(full,use="complete"),2)
# Out:
# [1] "korea"
#             Exchange X1Y_Yield_d X1Y_Yield_f Int_d Int_f Infl_d Infl_f GDPG_d
# Exchange        1.00       -0.30       -0.12 -0.28 -0.12  -0.42   0.22   0.29
# X1Y_Yield_d    -0.30        1.00        0.47  0.15  0.06   0.18  -0.29   0.10
# X1Y_Yield_f    -0.12        0.47        1.00  0.28  0.14  -0.02  -0.29   0.10
# Int_d          -0.28        0.15        0.28  1.00  0.80   0.52   0.01  -0.14
# Int_f          -0.12        0.06        0.14  0.80  1.00   0.67   0.38  -0.05
# Infl_d         -0.42        0.18       -0.02  0.52  0.67   1.00   0.48  -0.18
# Infl_f          0.22       -0.29       -0.29  0.01  0.38   0.48   1.00  -0.08
# GDPG_d          0.29        0.10        0.10 -0.14 -0.05  -0.18  -0.08   1.00
# GDPG_f          0.05       -0.09       -0.25 -0.47 -0.62  -0.56  -0.55   0.09
# BOT_f           0.04        0.14        0.06 -0.42 -0.69  -0.58  -0.52  -0.01
# BOT_d           0.72        0.02        0.23 -0.10 -0.10  -0.45  -0.20   0.47
# FER_f          -0.41       -0.11       -0.26 -0.62 -0.71  -0.28  -0.31  -0.11
#             GDPG_f BOT_f BOT_d FER_f
# Exchange      0.05  0.04  0.72 -0.41
# X1Y_Yield_d  -0.09  0.14  0.02 -0.11
# X1Y_Yield_f  -0.25  0.06  0.23 -0.26
# Int_d        -0.47 -0.42 -0.10 -0.62
# Int_f        -0.62 -0.69 -0.10 -0.71
# Infl_d       -0.56 -0.58 -0.45 -0.28
# Infl_f       -0.55 -0.52 -0.20 -0.31
# GDPG_d        0.09 -0.01  0.47 -0.11
# GDPG_f        1.00  0.63  0.12  0.60
# BOT_f         0.63  1.00  0.16  0.50
# BOT_d         0.12  0.16  1.00 -0.36
# FER_f         0.60  0.50 -0.36  1.00

# %%
## mexico
ex_rates <- read.csv('topfive.csv')
ex_rates <- subset(ex_rates, ex_rates$Country.y=='mexico')
    
full <- subset(ex_rates, select = c(Pct_Chg, Exchange, X1Y_Yield_d, 
                X1Y_Yield_f, Int_d, Int_f,  Infl_d, Infl_f, GDPG_d,
                GDPG_f, BOT_f, BOT_d, FER_f))

print('mexico')
full <- full[,-1]
rownames(full) <- 1:nrow(full)
round(cor(full,use="complete"),2)
# Out:
# [1] "mexico"
#             Exchange X1Y_Yield_d X1Y_Yield_f Int_d Int_f Infl_d Infl_f GDPG_d
# Exchange        1.00       -0.07       -0.18 -0.69 -0.71  -0.71  -0.19   0.05
# X1Y_Yield_d    -0.07        1.00        0.63  0.07 -0.38   0.17  -0.56   0.09
# X1Y_Yield_f    -0.18        0.63        1.00  0.15 -0.21   0.25  -0.58  -0.07
# Int_d          -0.69        0.07        0.15  1.00  0.75   0.49  -0.08  -0.38
# Int_f          -0.71       -0.38       -0.21  0.75  1.00   0.50   0.40  -0.28
# Infl_d         -0.71        0.17        0.25  0.49  0.50   1.00  -0.15  -0.21
# Infl_f         -0.19       -0.56       -0.58 -0.08  0.40  -0.15   1.00   0.22
# GDPG_d          0.05        0.09       -0.07 -0.38 -0.28  -0.21   0.22   1.00
# GDPG_f         -0.55        0.15        0.06  0.24  0.37   0.27   0.30   0.37
# BOT_f          -0.04        0.20        0.06 -0.18 -0.25   0.00  -0.09   0.15
# BOT_d           0.67       -0.14       -0.29 -0.83 -0.66  -0.75   0.21   0.38
# FER_f           0.54        0.20        0.00 -0.61 -0.73  -0.34  -0.22   0.61
#             GDPG_f BOT_f BOT_d FER_f
# Exchange     -0.55 -0.04  0.67  0.54
# X1Y_Yield_d   0.15  0.20 -0.14  0.20
# X1Y_Yield_f   0.06  0.06 -0.29  0.00
# Int_d         0.24 -0.18 -0.83 -0.61
# Int_f         0.37 -0.25 -0.66 -0.73
# Infl_d        0.27  0.00 -0.75 -0.34
# Infl_f        0.30 -0.09  0.21 -0.22
# GDPG_d        0.37  0.15  0.38  0.61
# GDPG_f        1.00  0.17 -0.15 -0.29
# BOT_f         0.17  1.00  0.20  0.14
# BOT_d        -0.15  0.20  1.00  0.45
# FER_f        -0.29  0.14  0.45  1.00

# %%
## canada
ex_rates <- read.csv('topfive.csv')
ex_rates <- subset(ex_rates, ex_rates$Country.y=='canada')
    
full <- subset(ex_rates, select = c(Pct_Chg, Exchange, X1Y_Yield_d, 
                X1Y_Yield_f, Int_d, Int_f,  Infl_d, Infl_f, GDPG_d,
                GDPG_f, BOT_f, BOT_d, FER_f))

print('canada')
full <- full[,-1]
rownames(full) <- 1:nrow(full)
round(cor(full,use="complete"),2)
# Out:
# [1] "canada"
#             Exchange X1Y_Yield_d X1Y_Yield_f Int_d Int_f Infl_d Infl_f GDPG_d
# Exchange        1.00        0.11        0.07  0.39  0.34  -0.06  -0.16   0.18
# X1Y_Yield_d     0.11        1.00        0.65  0.03  0.02   0.05  -0.14   0.24
# X1Y_Yield_f     0.07        0.65        1.00 -0.21 -0.27  -0.06  -0.31  -0.14
# Int_d           0.39        0.03       -0.21  1.00  0.97   0.73   0.61   0.47
# Int_f           0.34        0.02       -0.27  0.97  1.00   0.72   0.65   0.49
# Infl_d         -0.06        0.05       -0.06  0.73  0.72   1.00   0.74   0.28
# Infl_f         -0.16       -0.14       -0.31  0.61  0.65   0.74   1.00   0.21
# GDPG_d          0.18        0.24       -0.14  0.47  0.49   0.28   0.21   1.00
# GDPG_f          0.16       -0.08       -0.13  0.58  0.54   0.66   0.31   0.32
# BOT_f           0.07        0.01        0.02  0.41  0.36   0.61   0.22   0.10
# BOT_d           0.61        0.23       -0.05  0.75  0.76   0.35   0.29   0.62
# FER_f          -0.55       -0.08        0.10 -0.82 -0.79  -0.55  -0.31  -0.54
#             GDPG_f BOT_f BOT_d FER_f
# Exchange      0.16  0.07  0.61 -0.55
# X1Y_Yield_d  -0.08  0.01  0.23 -0.08
# X1Y_Yield_f  -0.13  0.02 -0.05  0.10
# Int_d         0.58  0.41  0.75 -0.82
# Int_f         0.54  0.36  0.76 -0.79
# Infl_d        0.66  0.61  0.35 -0.55
# Infl_f        0.31  0.22  0.29 -0.31
# GDPG_d        0.32  0.10  0.62 -0.54
# GDPG_f        1.00  0.88  0.27 -0.65
# BOT_f         0.88  1.00  0.11 -0.48
# BOT_d         0.27  0.11  1.00 -0.85
# FER_f        -0.65 -0.48 -0.85  1.00
